# %%
import pandas as pd
import requests
response = requests.get('https://finalspaceapi.com/api/v0/episode/')
df = pd.DataFrame(response.json())
df.set_index('id',inplace=True)
df.iloc[:,:4]
# Out:
#                             name    air_date             director  \
# id
# 1                      Chapter 1  02/15/2018         Mike Roberts
# 2                      Chapter 2  02/15/2018         Mike Roberts
# 3                      Chapter 3  02/26/2018         Mike Roberts
# 4                      Chapter 4  03/19/2018         Mike Roberts
# 5                      Chapter 5  03/19/2018         Mike Roberts
# 6                      Chapter 6  03/26/2018         Mike Roberts
# 7                      Chapter 7  04/09/2018         Mike Roberts
# 8                      Chapter 8  04/16/2018         Mike Roberts
# 9                      Chapter 9  04/23/2018         Mike Roberts
# 10                    Chapter 10  04/30/2018         Mike Roberts
# 11              The Toro Regatta  06/22/2019         Ben Bjelajac
# 12               The Happy Place  06/22/2019    Yoriaki Mochizuki
# 13           The Grand Surrender  07/08/2019  Anne Walker Farrell
# ...

# %%
df.to_csv('FinalSpace.csv')

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df['Name']
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
df['title'] = df['Name'].str.split(',', expand=True)[1].str.split('.', expand=True)[0]
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 285         1177         0       3             Dennis, Mr. William    male
# 210         1102         0       3     Andersen, Mr. Albert Karvin    male
# 365         1257         1       3  Sage, Mrs. John (Annie Bullen)  female
# 253         1145         0       3        Salander, Mr. Karl Johan    male
# 269         1161         0       3               Pokrnic, Mr. Mate    male
#
#       Age  SibSp  Parch     Ticket     Fare Cabin Embarked title
# 285  36.0      0      0  A/5 21175   7.2500   NaN        S    Mr
# 210  32.0      0      0     C 4001  22.5250   NaN        S    Mr
# 365   NaN      1      9   CA. 2343  69.5500   NaN        S   Mrs
# 253  24.0      0      0       7266   9.3250   NaN        S    Mr
# 269  17.0      0      0     315095   8.6625   NaN        S    Mr

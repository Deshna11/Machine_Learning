# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# ##### 1. SCATTER PLOT (NUMERICAL-NUMERICAL)
# ###### PAIR PLOT(VERY USEFUL), LINE PLOT CAN ALSO BE USED

# %%
sns.scatterplot(x=df['Age'], y=df['Fare'], hue=df['Sex'], style=df['Survived'], size=df['Embarked']) # more than 2 column analysis- multivariate
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %% [markdown]
# ##### BAR PLOT (NUMERICAL-CATEGORICAL)

# %%
sns.barplot(x=df['Pclass'], y=df['Fare'],hue=df['Sex'] )
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# ###### BOXPLOT, DISTPLOT, PAIRPLOT (NUMERICAL-CATEGORICAL)
# ###### HEAT_MAP, CLUSTER_MAP (CATEGORICAL - CATEGORICAL)
